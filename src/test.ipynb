# %%
import pandas as pd

# %%
df = pd.read_excel("../Patient_Data_KDAG_Hackathon.xlsx")
df.head()
# Out:
#    Patient ID Physician_ID Date_of_Visit  Year of Birth Gender  \
# 0       16445     axt01951    2020-01-12         1962.0      F
# 1       16445     axt01951    2019-09-25         1962.0      F
# 2       16445     axt01951    2019-02-12         1962.0      F
# 3       16445     axt01951    2019-11-07         1962.0      F
# 4       16445     axt01951    2019-04-17         1962.0      F
#
#   Geographical_State
# 0                 ME
# 1                 ME
# 2                 ME
# 3                 ME
# 4                 ME

# %%
# frequency of Patients for each Physician_ID

df['Physician_ID'].value_counts().sort_index()

# find the top 25 Physician_ID with the highest number of patients
df['Physician_ID'].value_counts().sort_index().nlargest(25)
# Out:
# axt01951    3140
# axt06977    1845
# axt01329    1766
# axt04883    1629
# axt08746    1590
# axt01659    1559
# axt04416    1458
# axt01746    1428
# axt05419    1401
# axt07349    1361
# axt00366    1360
# axt00417    1331
# axt02184    1265
# axt07974    1253
# axt03761    1211
# axt03276    1205
# axt03668    1113
# axt05820    1089
# axt08938    1086
# axt08950    1083
# axt04647    1060
# axt07747    1048
# axt01932    1018
# axt04249    1007
# axt01292     993
# Name: Physician_ID, dtype: int64

# %%
df['Patient ID'].nunique()
# Out:
# 39956

# %%
df1 = pd.read_excel("../HCP_Data_KDAG_Hackathon.xlsx")

# %%
df1[df1['Physician_ID'] == 'axt04883']
# Out:
#        Physician_ID  Time_Period  Brand_Rx  Market_Rx  Sales_Rep_Calls  \
# 278274     axt04883     20190104     9.704  102.45672                1
# 278275     axt04883     20190111     6.887  104.10569                1
# 278276     axt04883     20190118     4.707   57.98026                1
# 278277     axt04883     20190125     9.884  145.97554                1
# 278278     axt04883     20190201     9.437   89.02017                1
# 278279     axt04883     20190208     2.812   88.98251                1
# 278280     axt04883     20190215     6.012  112.87778                1
# 278281     axt04883     20190222     8.413  112.63299                1
# 278282     axt04883     20190301    11.152  118.82806                1
# 278283     axt04883     20190308     6.507  106.65043                1
# 278284     axt04883     20190315     6.725  112.38820                1
# 278285     axt04883     20190322     7.917  109.03646                1
# ...

# %%
df2.corr()
# Out:
# /var/folders/qb/stptmtq13_9gt1v1pzd4g4s00000gn/T/ipykernel_13379/1778878097.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df2.corr()
#                            Time_Period  Brand_Rx  Market_Rx  Sales_Rep_Calls  \
# Time_Period                   1.000000 -0.039524  -0.066676         0.047547
# Brand_Rx                     -0.039524  1.000000   0.337137         0.100311
# Market_Rx                    -0.066676  0.337137   1.000000         0.234843
# Sales_Rep_Calls               0.047547  0.100311   0.234843         1.000000
# Samples_Dropped               0.014699  0.139735   0.056852         0.257470
# Emails_Delivered              0.054642  0.043132   0.078514         0.143177
# Speaker_Programs_Attended          NaN       NaN        NaN              NaN
# ...

# %%
df1['Market_Rx'].nlargest(25)
# Out:
# 111198    259.96698
# 111200    251.47196
# 111204    250.17000
# 111186    240.97020
# 111206    234.53303
# 111151    231.40725
# 111170    228.35679
# 111196    227.16512
# 111194    226.63519
# 111154    222.45762
# 111172    219.30763
# 111189    218.83688
# 111177    218.73197
# 111192    217.33048
# 111181    216.21682
# 111168    211.08968
# 111188    209.61287
# 111199    206.42522
# 111158    206.21540
# 111153    203.38014
# 111157    203.33710
# 111193    202.30683
# 111190    202.26648
# 111160    201.72041
# 111195    198.52200
# Name: Market_Rx, dtype: float64
